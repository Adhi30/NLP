# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x:1 if x == 'spam' else 0)

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size = 0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:4]
# Out:
# 918     When people see my msgs, They think Iam addict...
# 350     Just checking in on you. Really do miss seeing...
# 1228           So ü'll be submitting da project tmr rite?
# 2000        LMAO where's your fish memory when I need it?
# Name: Message, dtype: object

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train[:4]
# Out:
# 918     0
# 350     0
# 1228    0
# 2000    0
# Name: spam, dtype: int64

# %%
type(X_train.values)
# Out:
# numpy.ndarray

# %% [markdown]
# **Create bag of words representation using CountVectorizer**

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <4457x7752 sparse matrix of type '<class 'numpy.int64'>'
# 	with 59230 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_train_cv.shape
# Out:
# (4457, 7752)

# %%
v.get_feature_names_out()[1771]
# Out:
# 'chat'

# %%
v.vocabulary_
# Out:
# {'when': 7493,
#  'people': 5145,
#  'see': 5987,
#  'my': 4667,
#  'msgs': 4625,
#  'they': 6849,
#  'think': 6856,
#  'iam': 3594,
#  'addicted': 832,
#  'to': 6943,
#  'msging': 4621,
#  'are': 1075,
#  'wrong': 7640,
#  'bcoz': 1292,
#  'don': 2426,
#  'know': 3965,
#  'that': 6822,
#  'sweet': 6663,
#  'friends': 3031,
#  'bslvyl': 1562,
#  'just': 3883,
#  'checking': 1785,
#  'in': 3654,
#  'on': 4931,
#  'you': 7715,
#  'really': 5609,
#  'do': 2397,
#  'miss': 4507,
#  'seeing': 5989,
#  'jeremiah': 3822,
#  'have': 3376,
#  'great': 3259,
#  'month': 4578,
#  'so': 6291,
#  'll': 4159,
#  'be': 1298,
#  'submitting': 6567,
#  'da': 2161,
#  'project': 5451,
#  'tmr': 6937,
#  'rite': 5803,
#  'lmao': 4162,
#  'where': 7497,
#  'your': 7720,
#  'fish': 2895,
#  'memory': 4444,
#  'need': 4727,
#  'it': 3771,
#  'stop': 6503,
#  'calling': 1647,
#  'everyone': 2687,
#  'saying': 5935,
#  'might': 4473,
#  'cancer': 1665,
#  'throat': 6884,
#  'hurts': 3582,
#  'talk': 6707,
#  'can': 1658,
#  'answering': 1010,
#  'everyones': 2688,
#  'calls': 1649,
#  'if': 3620,
#  'get': 3145,
#  'one': 4936,
#  'more': 4585,
#  'call': 1634,
#  'not': 4828,
#  'babysitting': 1225,
#  'monday': 4567,
#  'ok': 4916,
#  'yeah': 7688,
#  'hopefully': 3515,
#  'tyler': 7116,
#  'could': 2051,
#  'maybe': 4402,
#  'ask': 1121,
#  'around': 1098,
#  'bit': 1390,
#  'hey': 3441,
#  'what': 7487,
#  'how': 3543,
#  'about': 779,
#  'started': 6459,
#  'aha': 895,
#  'there': 6843,
#  'is': 3762,
#  'no': 4791,
#  'sense': 6017,
#  'foot': 2958,
#  'and': 984,
#  'penis': 5143,
#  'meet': 4426,
#  'at': 1145,
#  'as': 1114,
#  'depends': 2270,
#  'wan': 7386,
#  'lor': 4204,
#  'time': 6911,
#  'should': 6125,
#  'come': 1929,
#  'tomorrow': 6969,
#  'hi': 3445,
#  'this': 6864,
#  'yijue': 7707,
#  '11': 276,
#  'doing': 2421,
#  'intro': 3734,
#  'covers': 2067,
#  'energy': 2608,
#  'trends': 7049,
#  'pros': 5471,
#  'cons': 1993,
#  'brief': 1529,
#  'description': 2280,
#  'of': 4893,
#  'nuclear': 4854,
#  'fusion': 3082,
#  'oso': 4997,
#  'history': 3462,
#  'iter': 3775,
#  'jet': 3829,
#  'got': 3224,
#  'abt': 786,
#  'half': 3325,
#  'pages': 5050,
#  'mail': 4318,
#  'panren': 5065,
#  'paru': 5097,
#  'buy': 1607,
#  'newspapers': 4763,
#  'already': 948,
#  'eh': 2561,
#  'ur': 7213,
#  'laptop': 4013,
#  'stock': 6495,
#  'lei': 4069,
#  'he': 3384,
#  'say': 5932,
#  'mon': 4566,
#  'muz': 4666,
#  'again': 881,
#  'take': 6700,
#  'look': 4193,
#  'freemsg': 3015,
#  'buffy': 1579,
#  '25': 370,
#  'love': 4225,
#  'satisfy': 5920,
#  'men': 4445,
#  'home': 3496,
#  'alone': 945,
#  'feeling': 2826,
#  'randy': 5574,
#  'reply': 5719,
#  'pix': 5226,
#  'qlynnbv': 5525,
#  'help08700621170150p': 3420,
#  'msg': 4619,
#  'send': 6012,
#  'txts': 7111,
#  'any': 1018,
#  'opening': 4956,
#  'for': 2964,
#  'mca': 4405,
#  'today': 6949,
#  'accept': 795,
#  'day': 2198,
#  'me': 4409,
#  'brother': 1550,
#  'sister': 6193,
#  'lover': 4230,
#  'dear1': 2209,
#  'best1': 1353,
#  'clos1': 1871,
#  'lvblefrnd': 4270,
#  'jstfrnd': 3867,
#  'cutefrnd': 2151,
#  'lifpartnr': 4103,
#  'belovd': 1343,
#  'swtheart': 6677,
#  'bstfrnd': 1565,
#  'rply': 5842,
#  'means': 4415,
#  'enemy': 2607,
#  'worries': 7616,
#  'hope': 3512,
#  'photo': 5193,
#  'shoot': 6111,
#  'went': 7474,
#  'well': 7468,
#  'spiffing': 6391,
#  'fun': 3071,
#  'workage': 7606,
#  'angry': 991,
#  'with': 7561,
#  'dr': 2451,
#  'guys': 3305,
#  'leaving': 4059,
#  'make': 4325,
#  'girl': 3163,
#  'happy': 3352,
#  'all': 936,
#  'difficult': 2335,
#  'girls': 3165,
#  'only': 4942,
#  'friend': 3030,
#  'companion': 1943,
#  'chef': 1795,
#  'lt': 4246,
#  'gt': 3285,
#  'good': 3209,
#  'listener': 4144,
#  'organizer': 4987,
#  'boyfriend': 1500,
#  'very': 7283,
#  'clean': 1860,
#  'sympathetic': 6680,
#  'athletic': 1147,
#  'warm': 7397,
#  'courageous': 2061,
#  'determined': 2294,
#  'true': 7063,
#  'dependable': 2268,
#  'intelligent': 3719,
#  'psychologist': 5488,
#  'pest': 5172,
#  'exterminator': 2747,
#  'psychiatrist': 5486,
#  'healer': 3393,
#  'stylist': 6562,
#  'driver': 2468,
#  'aaniye': 765,
#  'pudunga': 5494,
#  'venaam': 7278,
#  'night': 4774,
#  'has': 3362,
#  'ended': 2600,
#  'another': 1004,
#  'morning': 4589,
#  'special': 6372,
#  'way': 7424,
#  'may': 4400,
#  'smile': 6260,
#  'like': 4111,
#  'the': 6826,
#  'sunny': 6615,
#  'rays': 5582,
#  'leaves': 4058,
#  'blue': 1431,
#  'bay': 1280,
#  'gud': 3290,
#  'mrng': 4616,
#  'whatever': 7488,
#  'lol': 4184,
#  'cant': 1669,
#  'pick': 5201,
#  'phone': 5188,
#  'right': 5786,
#  'now': 4843,
#  'pls': 5261,
#  'message': 4456,
#  'secret': 5978,
#  'admirer': 842,
#  'who': 7508,
#  'looking': 4197,
#  'contact': 2002,
#  'find': 2878,
#  'out': 5007,
#  'reveal': 5768,
#  'thinks': 6860,
#  '09058094599': 185,
#  'honeybee': 3503,
#  'said': 5888,
#  'sweetest': 6664,
#  'world': 7612,
#  'god': 3191,
#  'laughed': 4031,
#  'amp': 972,
#  'wait': 7367,
#  'havnt': 3383,
#  'met': 4463,
#  'person': 5164,
#  'reading': 5599,
#  'moral': 4584,
#  'even': 2678,
#  'crack': 2074,
#  'jokes': 3849,
#  'gm': 3180,
#  'gn': 3182,
#  'ge': 3126,
#  'huh': 3567,
#  'hyde': 3590,
#  'park': 5086,
#  'mel': 4436,
#  'ah': 894,
#  'opps': 4964,
#  'confused': 1984,
#  'anyway': 1029,
#  'tt': 7080,
#  'best': 1352,
#  'choice': 1827,
#  'den': 2258,
#  'we': 7428,
#  'juz': 3889,
#  'want': 7391,
#  'funk': 3076,
#  'up': 7197,
#  'fone': 2950,
#  'weekly': 7455,
#  'new': 4755,
#  'tone': 6971,
#  'tones2u': 6973,
#  'text': 6797,
#  'www': 7651,
#  'ringtones': 5797,
#  'co': 1895,
#  'uk': 7132,
#  'original': 4990,
#  'tones': 6972,
#  '3gbp': 466,
#  'network': 4746,
#  'operator': 4959,
#  'rates': 5579,
#  'apply': 1052,
#  'pa': 5042,
#  'flippin': 2918,
#  'shit': 6098,
#  'yet': 7702,
#  'wil': 7527,
#  'minutes': 4497,
#  'space': 6360,
#  'hiya': 3468,
#  'was': 7404,
#  'last': 4021,
#  've': 7272,
#  'been': 1319,
#  'naughty': 4710,
#  'bought': 1475,
#  'myself': 4672,
#  'clothes': 1879,
#  'little': 4150,
#  'ready': 5600,
#  'shopping': 6114,
#  'tho': 6871,
#  'kind': 3947,
#  'wanna': 7389,
#  'yes': 7699,
#  'innocent': 3699,
#  'am': 959,
#  'interested': 3722,
#  'office': 4903,
#  'misplaced': 4506,
#  'number': 4858,
#  'sending': 6014,
#  'texts': 6807,
#  'old': 4927,
#  'wondering': 7592,
#  'why': 7515,
#  'heard': 3397,
#  'from': 3047,
#  'year': 7689,
#  'mcat': 4406,
#  'atlanta': 1149,
#  'freezing': 3017,
#  'craving': 2081,
#  'ice': 3603,
#  'fml': 2938,
#  'babe': 1220,
#  'better': 1357,
#  'reboot': 5618,
#  'ym': 7708,
#  'did': 2321,
#  'posted': 5339,
#  'facebook': 2760,
#  'grins': 3269,
#  'but': 1603,
#  'thanks': 6814,
#  'thinking': 6859,
#  'pic': 5200,
#  'please': 5253,
#  're': 5589,
#  'urgent': 7217,
#  'important': 3645,
#  'information': 3687,
#  '02': 7,
#  'user': 7234,
#  'lucky': 4253,
#  'log': 4176,
#  'onto': 4945,
#  'http': 3558,
#  'urawinner': 7214,
#  'com': 1923,
#  'fantastic': 2792,
#  'surprise': 6641,
#  'awaiting': 1197,
#  'made': 4303,
#  'too': 6982,
#  'sorry': 6339,
#  'later': 4026,
#  'meeting': 4428,
#  'thing': 6854,
#  'related': 5673,
#  'trade': 7018,
#  'arul': 1112,
#  'crucify': 2105,
#  'told': 6959,
#  'earlier': 2517,
#  'vikky': 7301,
#  'oh': 4913,
#  'lot': 4212,
#  'eggs': 2559,
#  'same': 5901,
#  'dun': 2498,
#  'wat': 7411,
#  'still': 6493,
#  'eating': 2533,
#  'these': 6845,
#  'ideas': 3612,
#  'tired': 6919,
#  'had': 3315,
#  'strong': 6536,
#  'arms': 1094,
#  'asked': 1123,
#  'money': 4569,
#  'far': 2794,
#  'coz': 2068,
#  'never': 4751,
#  'go': 3185,
#  'before': 1325,
#  'pay': 5118,
#  'over': 5023,
#  'yrs': 7732,
#  'its': 3777,
#  'took': 6983,
#  'long': 4190,
#  'omw': 4930,
#  'rightio': 5787,
#  '48': 517,
#  'then': 6837,
#  'arent': 1078,
#  'bright': 1530,
#  'early': 2519,
#  'dear': 2208,
#  'umma': 7138,
#  'she': 6075,
#  'called': 1641,
#  'promise': 5456,
#  'getting': 3150,
#  'soon': 6329,
#  'let': 4083,
#  'genius': 3135,
#  'does': 2407,
#  'stay': 6470,
#  'bed': 1313,
#  'doesn': 2409,
#  'recovery': 5643,
#  'id': 3608,
#  'rather': 5580,
#  'pass': 5099,
#  'while': 7503,
#  'having': 3381,
#  'cooped': 2026,
#  'congrats': 1986,
#  'mobile': 4542,
#  '3g': 465,
#  'videophones': 7295,
#  'yours': 7724,
#  '09063458130': 212,
#  'videochat': 7294,
#  'wid': 7519,
#  'mates': 4383,
#  'play': 5244,
#  'java': 3806,
#  'games': 3098,
#  'dload': 2395,
#  'polyph': 5304,
#  'music': 4659,
#  'noline': 4805,
#  'rentl': 5709,
#  'actually': 826,
#  'nvm': 4867,
#  'hella': 3415,
#  'cash': 1703,
#  'ish': 3764,
#  'sian': 6152,
#  'aft': 873,
#  'supervisor': 6623,
#  'work': 7605,
#  'liao': 4090,
#  'working': 7609,
#  'rent': 5706,
#  'bank': 1249,
#  'authorise': 1179,
#  'payment': 5125,
#  'sarcasm': 5911,
#  'nt': 4849,
#  'scarcasim': 5940,
#  'cup': 2135,
#  'coffee': 1905,
#  'animation': 993,
#  'will': 7531,
#  'an': 980,
#  'hour': 3535,
#  'taking': 6704,
#  'leave': 4057,
#  'bec': 1306,
#  'height': 3411,
#  'confidence': 1979,
#  'aeronautics': 859,
#  'professors': 5445,
#  'wer': 7476,
#  'calld': 1640,
#  'askd': 1122,
#  'sit': 6195,
#  'aeroplane': 860,
#  'aftr': 879,
#  'sat': 5916,
#  'dat': 2190,
#  'plane': 5236,
#  'ws': 7642,
#  'by': 1619,
#  'their': 6831,
#  'students': 6546,
#  'dey': 2304,
#  'hurried': 3579,
#  'bt': 1566,
#  'didnt': 2324,
#  'move': 4605,
#  'wont': 7594,
#  'start': 6458,
#  'datz': 2196,
#  'valued': 7259,
#  'customer': 2146,
#  'pleased': 5254,
#  'advise': 856,
#  'following': 2946,
#  'recent': 5628,
#  'review': 5772,
#  'mob': 4541,
#  'awarded': 1200,
#  '1500': 310,
#  'bonus': 1450,
#  'prize': 5427,
#  '09066364589': 236,
#  'line': 4124,
#  'till': 6909,
#  'forget': 2971,
#  'or': 4971,
#  'realize': 5607,
#  'cannot': 1668,
#  'mum': 4647,
#  'repent': 5714,
#  'hear': 3396,
#  'settling': 6040,
#  'happenin': 3345,
#  'wit': 7560,
#  'ola': 4925,
#  'aiyo': 913,
#  'pai': 5051,
#  'seh': 5995,
#  'noe': 4795,
#  'scared': 5941,
#  'rem': 5685,
#  'die': 2326,
#  'hee': 3408,
#  'become': 1309,
#  'lookin': 4196,
#  'oredi': 4982,
#  'leh': 4068,
#  'sleep': 6224,
#  'rest': 5749,
#  'part': 5089,
#  'yep': 7697,
#  'pink': 5220,
#  'furniture': 3080,
#  'couple': 2059,
#  'pics': 5205,
#  'fb': 2815,
#  'snow': 6286,
#  'outside': 5016,
#  'waking': 7372,
#  'hello': 3416,
#  'goes': 3193,
#  'wish': 7553,
#  'fine': 2880,
#  'some': 6305,
#  'job': 3838,
#  'prospects': 5472,
#  'boytoy': 1502,
#  'teasing': 6753,
#  'kiss': 3955,
#  'coming': 1934,
#  'driving': 2470,
#  'clas': 1852,
#  'sexy': 6048,
#  'cum': 2132,
#  'im': 3632,
#  'wet': 7485,
#  'porn': 5318,
#  'free': 3008,
#  'recd': 5621,
#  '150p': 311,
#  'inc': 3656,
#  'vat': 7268,
#  'cancel': 1662,
#  'were': 7477,
#  'going': 3198,
#  'drunk': 2480,
#  'dinner': 2350,
#  'tonight': 6978,
#  'bears': 1301,
#  'nick': 4769,
#  'tom': 6964,
#  'pete': 5173,
#  'dick': 2318,
#  'fact': 2762,
#  'types': 7118,
#  'try': 7071,
#  'gay': 3117,
#  'chat': 1771,
#  'upload': 7206,
#  '08718730666': 155,
#  '10p': 273,
#  'min': 4480,
#  '08712460324': 115,
#  'dunno': 2500,
#  'lazy': 4041,
#  'url': 7223,
#  'boys': 1501,
#  'hot': 3530,
#  'xxx': 7667,
#  'sent': 6020,
#  'direct': 2355,
#  'txt': 7103,
#  '69855': 608,
#  '24hrs': 367,
#  '50p': 553,
#  'per': 5147,
#  'stopbcm': 6506,
#  'sf': 6051,
#  'wc1n3xx': 7427,
#  'food': 2954,
#  'fridge': 3028,
#  'meal': 4410,
#  'together': 6953,
#  'thinkin': 6858,
#  'him': 3455,
#  'win': 7534,
#  '200': 346,
#  'spree': 6420,
#  'every': 2684,
#  'week': 7451,
#  'starting': 6460,
#  'store': 6511,
#  '88039': 719,
#  'skilgme': 6209,
#  'tscs08714740323': 7077,
#  '1winawk': 342,
#  'age16': 885,
#  '50perweeksub': 554,
#  'alex': 927,
#  'knows': 3968,
#  'guy': 3304,
#  'sells': 6007,
#  'mids': 4472,
#  'down': 2443,
#  'south': 6355,
#  'tampa': 6716,
#  'set': 6035,
#  'also': 951,
#  'watch': 7412,
#  'pm': 5268,
#  'show': 6131,
#  'thats': 6825,
#  'nice': 4767,
#  'bad': 1230,
#  'eat': 2530,
#  'official': 4905,
#  'england': 2613,
#  'poly': 5300,
#  'ringtone': 5795,
#  'colour': 1920,
#  'flag': 2905,
#  'yer': 7698,
#  'tonights': 6979,
#  'game': 3097,
#  '84199': 695,
#  'optout': 4970,
#  'eng': 2609,
#  'box39822': 1490,
#  'w111wx': 7346,
#  '50': 546,
#  'weightloss': 7460,
#  'loads': 4166,
#  'ebay': 2534,
#  'something': 6313,
#  'give': 3168,
#  'midnight': 4471,
#  'earliest': 2518,
#  'nothing': 4833,
#  'spl': 6400,
#  'whr': 7514,
#  'ru': 5850,
#  'arngd': 1096,
#  'marriage': 4365,
#  'walkin': 7377,
#  'unfortuntly': 7168,
#  'snake': 6279,
#  'bites': 1394,
#  'dancing': 2173,
#  'frnt': 3044,
#  'sayin': 5934,
#  'bite': 1393,
#  'perumbavoor': 5170,
#  'whens': 7496,
#  'radio': 5550,
#  'us': 7226,
#  'ringtoneking': 5796,
#  '84484': 696,
#  'back': 1227,
#  'thursday': 6894,
#  'yay': 7686,
#  'gonna': 3208,
#  'cheers': 1790,
#  'everything': 2690,
#  'alright': 949,
#  'hows': 3547,
#  'school': 5946,
#  'ding': 2348,
#  'ya': 7675,
#  'break': 1518,
#  'fassyole': 2798,
#  'blacko': 1400,
#  'londn': 4186,
#  '09066612661': 242,
#  'landline': 4003,
#  'complimentary': 1958,
#  'lux': 4267,
#  'costa': 2043,
#  'del': 2244,
#  'sol': 6299,
#  'holiday': 3491,
#  '1000': 264,
#  'await': 1196,
#  'collection': 1917,
#  'ppm': 5355,
#  '150': 309,
#  'sae': 5882,
#  'cs': 2111,
#  'james': 3795,
#  '28': 379,
#  'eh74rr': 2562,
#  'wen': 7471,
#  'lovable': 4224,
#  'bcums': 1295,
#  'dnt': 2396,
#  'seriously': 6029,
#  'being': 1336,
#  'most': 4594,
#  'childish': 1808,
#  'showing': 6136,
#  'deep': 2229,
#  'affection': 864,
#  'care': 1681,
#  'luv': 4264,
#  'kettoda': 3924,
#  'manda': 4341,
#  'mm': 4529,
#  'railway': 5556,
#  'yup': 7738,
#  'happen': 3342,
#  'okie': 4921,
#  'nope': 4814,
#  'market': 4360,
#  'openings': 4957,
#  'room': 5826,
#  'til': 6908,
#  'after': 874,
#  'thanksgiving': 6816,
#  'without': 7565,
#  'upcharge': 7199,
#  'bill': 1374,
#  'letters': 4086,
#  'expecting': 2727,
#  'orange': 4974,
#  'isn': 3767,
#  'norm': 4818,
#  'finish': 2883,
#  '15': 308,
#  'cos': 2040,
#  'st': 6436,
#  'tests': 6793,
#  'sort': 6340,
#  'library': 4093,
#  'stuff': 6552,
#  'point': 5291,
#  'tomo': 6967,
#  'letter': 4085,
#  'access': 796,
#  'end': 2599,
#  'march': 4356,
#  'lets': 4084,
#  'saturday': 5923,
#  'convenience': 2015,
#  'ranjith': 5577,
#  'cal': 1628,
#  'drpd': 2476,
#  'deeraj': 2231,
#  'deepak': 2230,
#  '5min': 572,
#  'hold': 3487,
#  'eerie': 2551,
#  'nokia': 4801,
#  '4u': 541,
#  'title': 6926,
#  '8007': 657,
#  'eg': 2556,
#  'dracula': 2452,
#  'titles': 6927,
#  'ghost': 3154,
#  'addamsfa': 830,
#  'munsters': 4653,
#  'exorcist': 2725,
#  'twilight': 7099,
#  'getzed': 3151,
#  'pobox36504w45wq': 5279,
#  'video': 7293,
#  'camera': 1655,
#  'phones': 5191,
#  'price': 5412,
#  'rental': 5707,
#  '12': 287,
#  'mths': 4630,
#  '500': 547,
#  'cross': 2100,
#  'ntwk': 4853,
#  'mins': 4494,
#  '100': 263,
#  'mobileupd8': 4546,
#  '08001950382': 55,
#  'call2optout': 1636,
#  '674': 601,
#  'them': 6833,
#  'raining': 5558,
#  'mah': 4314,
#  'hard': 3353,
#  'orchard': 4977,
#  'hmm': 3474,
#  'eye': 2752,
#  'sore': 6336,
#  'rats': 5581,
#  'ever': 2683,
#  'vote': 7335,
#  'next': 4764,
#  'themes': 6835,
#  'fyi': 3085,
#  'sporadically': 6413,
#  'bc': 1285,
#  'doin': 2419,
#  'rose': 5831,
#  'needs': 4731,
#  'water': 7416,
#  'season': 5972,
#  'change': 1749,
#  'poet': 5290,
#  'imagination': 3635,
#  'sms': 6272,
#  'lovely': 4228,
#  'frndship': 3040,
#  'forever': 2969,
#  'wine': 7541,
#  'dine': 2346,
#  'lady': 3998,
#  'thought': 6876,
#  'living': 4156,
#  'life': 4099,
#  'perfect': 5151,
#  'partner': 5093,
#  'name': 4686,
#  'age': 884,
#  'join': 3844,
#  'community': 1940,
#  '100p': 267,
#  'done': 2428,
#  '5000': 548,
#  '09050090044': 175,
#  'toclaim': 6948,
#  'tcs': 6741,
#  'pobox334': 5278,
#  'stockport': 6497,
#  'sk38xh': 6207,
#  'cost': 2042,
#  'max10mins': 4396,
#  'until': 7195,
#  'trying': 7073,
#  'house': 3538,
#  'thangam': 6812,
#  'feel': 2824,
#  'stupid': 6557,
#  'always': 957,
#  'believe': 1337,
#  'those': 6872,
#  'pandy': 5062,
#  'mental': 4447,
#  'popping': 5317,
#  'ibuprofens': 3601,
#  'help': 3419,
#  'gram': 3243,
#  'usually': 7239,
#  'runs': 5864,
#  'eighth': 2564,
#  'smarter': 6253,
#  'though': 6875,
#  'gets': 3147,
#  'almost': 944,
#  'whole': 7510,
#  'second': 5975,
#  'slowly': 6245,
#  'vomit': 7332,
#  'petey': 5175,
#  'noi': 4796,
#  'wanted': 7393,
#  'avent': 1189,
#  'spoken': 6410,
#  'alrite': 950,
#  'nit': 4784,
#  'js': 3864,
#  'creepy': 2094,
#  'crazy': 2083,
#  'running': 5863,
#  'managed': 4338,
#  'needed': 4729,
#  'oxygen': 5038,
#  'resort': 5741,
#  'roller': 5822,
#  'option': 4969,
#  'accidentally': 800,
#  'deleted': 2248,
#  'suppose': 6629,
#  'put': 5515,
#  'sim': 6171,
#  'archive': 1073,
#  'haiz': 3324,
#  'sad': 5881,
#  'black': 1398,
#  'shirt': 6096,
#  'jeans': 3815,
#  'thk': 6865,
#  'awesome': 1202,
#  'restocked': 5752,
#  'none': 4808,
#  'nowhere': 4846,
#  'ikno': 3624,
#  'doesdiscount': 2408,
#  'shitinnit': 6101,
#  'queen': 5529,
#  'royal': 5839,
#  'wedding': 7445,
#  'filthy': 2871,
#  'stories': 6513,
#  'waiting': 7370,
#  'truro': 7067,
#  'hospital': 3525,
#  'ext': 2746,
#  'here': 3432,
#  'side': 6157,
#  'whats': 7489,
#  'plan': 5235,
#  'reached': 5592,
#  'tomorro': 6968,
#  'easy': 2529,
#  'mate': 4382,
#  'guess': 3294,
#  'quick': 5534,
#  'drink': 2463,
#  'ambitious': 962,
#  'hamster': 3330,
#  'dead': 2204,
#  '1pm': 336,
#  'mrt': 4617,
#  'oooh': 4949,
#  'plenty': 5258,
#  '40': 480,
#  'years': 7690,
#  'thousands': 6878,
#  'ladies': 3997,
#  'tattoos': 6728,
#  'anything': 1026,
#  'ago': 892,
#  'much': 4637,
#  '09066649731from': 243,
#  'ibiza': 3597,
#  '10': 262,
#  '000': 1,
#  'po': 5270,
#  'box': 1481,
#  '434': 498,
#  'sk3': 6206,
#  '8wp': 741,
#  '150ppm': 315,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([ 832, 1075, 1292, 1562, 2426, 3031, 3594, 3965, 4621, 4625, 4667,
#         5145, 5987, 6663, 6822, 6849, 6856, 6943, 7493, 7640], dtype=int64),)
